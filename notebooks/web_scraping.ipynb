# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %% [markdown]
# # Create Growth Rate Dataframe

# %%
url = "https://serenesforest.net/the-sacred-stones/characters/growth-rates/"
page = requests.get(url)
soup = BeautifulSoup(page.content, "html.parser")
tables = soup.find_all("table")
rows = tables[0].find_all('tr')
print(rows[0:2])
# Out:
# [<tr>
# <th style="width: 23%;">Name</th>
# <th style="width: 11%;">HP</th>
# <th style="width: 11%;">S/M</th>
# <th style="width: 11%;">Skl</th>
# <th style="width: 11%;">Spd</th>
# <th style="width: 11%;">Lck</th>
# <th style="width: 11%;">Def</th>
# <th style="width: 11%;">Res</th>
# </tr>, <tr>
# <td>Eirika</td>
# <td>70</td>
# <td>40</td>
# <td>60</td>
# <td>60</td>
# <td>60</td>
# <td>30</td>
# <td>30</td>
# </tr>]

# %%
def extract_alt_text(image_info):
    if image_info['alt']:
        return image_info['alt']
    return

# %%
def scrape_table(table, game_title: str) -> pd.DataFrame:
    """
    Designed to scrape web tables found on serenesforest
    Serenes frequently uses multiple table header rows so this function
        takes that into account
    Note that header_found here is important as sometimes header rows use SLIGHTLY
        different strings so this is the safest route I could come up with.
        I really only want the first row of headers per table.
    Function also accounts for cells containing images and extracts their alt text to use as data.
    """
    data = []
    columns = []
    header_found = False
    
    for index, row in enumerate(table.find_all('tr')):
        row_data = []
        if not header_found:
            headers = row.find_all('th')
            if headers:
                header_found = True
                columns = [header.text for header in headers]
    
        for cell in row.find_all('td'):
            images = cell.find_all('img')
            if images:
                cell_data = [extract_alt_text(image) for image in images]
                if cell.text:
                    text = cell.text.replace(',', '').split()
                    cell_data = [f"{text[i]} {alt_text}" for i, alt_text in enumerate(cell_data)]
                row_data.append(cell_data)
            else:
                row_data.append(cell.text)
    
        if row_data:
            data.append(row_data)
        
    df = pd.DataFrame(data, columns=columns)
    df['Game'] = game_title

    return df

# %%
df = scrape_table(tables[0], 'the-sacred-stones')
df
# Out:
#                Name   HP S/M Skl Spd Lck  Def Res               Game
# 0            Eirika   70  40  60  60  60   30  30  the-sacred-stones
# 1              Seth   90  50  45  45  25   40  30  the-sacred-stones
# 2             Franz   80  40  40  50  40   25  20  the-sacred-stones
# 3           Gilliam   90  45  35  30  30   55  20  the-sacred-stones
# 4           Moulder   70  40  50  40  20   25  25  the-sacred-stones
# 5           Vanessa   50  35  55  60  50   20  30  the-sacred-stones
# 6              Ross   70  50  35  30  40   25  20  the-sacred-stones
# 7            Garcia   80  65  40  20  40   25  15  the-sacred-stones
# 8             Neimi   55  45  50  60  50   15  35  the-sacred-stones
# 9              Colm   75  40  40  65  45   25  20  the-sacred-stones
# 10            Artur   55  50  50  40  25   15  55  the-sacred-stones
# 11             Lute   45  65  30  45  45   15  40  the-sacred-stones
# 12          Natasha   50  60  25  40  60   15  55  the-sacred-stones
# 13           Joshua   80  35  55  55  30   20  20  the-sacred-stones
# 14          Ephraim   80  55  55  45  50   35  25  the-sacred-stones
# 15            Forde   85  40  50  45  35   20  25  the-sacred-stones
# 16             Kyle   90  50  40  40  20   25  20  the-sacred-stones
# 17             Tana   65  45  40  65  60   20  25  the-sacred-stones
# 18           Amelia   60  35  40  40  50   30  15  the-sacred-stones
# 19            Innes   75  40  40  45  45   20  25  the-sacred-stones
# 20            Gerik   90  45  40  30  30   35  25  the-sacred-stones
# 21           Tethys   85   5  10  70  80   30  75  the-sacred-stones
# 22           Marisa   75  30  55  60  50   15  25  the-sacred-stones
# 23        L’Arachel   45  50  45  45  65   15  50  the-sacred-stones
# 24            Dozla   85  50  35  40  30   30  25  the-sacred-stones
# 25            Saleh   50  30  25  40  40   30  35  the-sacred-stones
# 26             Ewan   50  45  40  35  50   15  40  the-sacred-stones
# 27           Cormag   85  55  40  45  35   25  15  the-sacred-stones
# 28           Rennac   65  25  45  60  25   25  30  the-sacred-stones
# 29          Duessel   85  55  40  30  20   45  30  the-sacred-stones
# 30            Knoll   70  50  40  35  20   10  45  the-sacred-stones
# 31            Myrrh  130  90  85  65  30  150  30  the-sacred-stones
# 32           Syrene   70  40  50  60  30   20  50  the-sacred-stones
# 33         Caellach   85  50  45  45  20   30  20  the-sacred-stones
# 34            Orson   80  55  45  40  25   45  30  the-sacred-stones
# 35             Riev   75  45  50  40  15   20  45  the-sacred-stones
# 36          Ismaire   75  30  60  55  30   20  25  the-sacred-stones
# 37           Selena   85  40  55  40  25   20  30  the-sacred-stones
# 38             Glen   85  45  50  45  20   35  40  the-sacred-stones
# 39           Hayden   70  40  45  45  40   25  25  the-sacred-stones
# 40           Valter   80  40  55  50  15   20  20  the-sacred-stones
# 41             Fado   85  55  40  30  25   45  25  the-sacred-stones
# 42             Lyon   85  50  55  55  30   45  55  the-sacred-stones
# 43  Knoll’s Phantom    0  50  50  40  55    0   0  the-sacred-stones
# 44   Ewan’s Phantom    0  70  40  20  40    0   0  the-sacred-stones
# 45   Lyon’s Phantom    0  60  45  30  60    0   0  the-sacred-stones

# %%
df.columns
# Out:
# Index(['Name', 'HP', 'S/M', 'Skl', 'Spd', 'Lck', 'Def', 'Res', 'Game'], dtype='object')

# %%
df.to_csv('../data/the-sacred-stones/growth-rates.csv', index=False)

# %% [markdown]
# # Create Base Stats Dataframe
#
# Gonna need some tinkering here. Weapon rank and affinity both use images to convey information.
#
# There's also actually two tables on this page. One for the base game characters and the other for creature campaign. Thankfully that's easy to handle.

# %%
url = "https://serenesforest.net/the-sacred-stones/characters/base-stats/"
page = requests.get(url)
soup = BeautifulSoup(page.content, "html.parser")
tables = soup.find_all("table")
dataframes = [scrape_table(table, 'the-sacred-stones') for table in tables]

for df in dataframes:
    display(df)
# Out:
#          Name  Lv           Class  HP Str Skl Spd Lck Def Res Mov Con  \
# 0      Eirika   1            Lord  16   4   8   9   5   3   1   5   5
# 1        Seth   1         Paladin  30  14  13  12  13  11   8   8  11
# 2       Franz   1        Cavalier  20   7   5   7   2   6   1   7   9
# 3     Gilliam   4          Knight  25   9   6   3   3   9   3   4  14
# 4     Vanessa   1  Pegasus Knight  17   5   7  11   4   6   5   7   5
# 5     Moulder   3          Priest  20   4   6   9   1   2   5   5   9
# 6        Ross   1      Journeyman  15   5   2   3   8   3   0   4   8
# 7      Garcia   4         Fighter  28   8   7   7   3   5   1   5  14
# 8       Neimi   1          Archer  17   4   5   6   4   3   2   5   5
# 9        Colm   2           Thief  18   4   4  10   8   3   1   6   6
# 10      Artur   2            Monk  19   6   6   8   2   2   6   5   6
# 11       Lute   1            Mage  17   6   6   7   8   3   5   5   3
# 12    Natasha   1          Cleric  18   2   4   8   6   2   6   5   4
# 13     Joshua   5        Myrmidon  24   8  13  14   7   5   2   5   8
# 14    Ephraim   4            Lord  23   8   9  11   8   7   2   5   8
# 15      Forde   6        Cavalier  24   7   8   8   7   8   2   7   9
# 16       Kyle   5        Cavalier  25   9   6   7   6   9   1   7  10
# 17      Orson   3         Paladin  34  15  13  11   4  13   7   8  12
# 18       Tana   4  Pegasus Knight  20   7   9  13   8   6   7   7   5
# 19     Amelia   1         Recruit  16   4   3   4   6   2   3   4   6
# 20      Innes   1          Sniper  31  14  13  15  14  10   9   6   9
# 21      Gerik  10       Mercenary  32  14  13  13   8  10   4   5  13
# 22     Tethys   1          Dancer  18   1   2  12  10   5   4   5   5
# 23     Marisa   5        Myrmidon  23   7  12  13   9   4   3   5   5
# 24  L’Arachel   3      Troubadour  18   6   6  10  12   5   8   6   5
# 25      Dozla   1       Berserker  43  16  11   9   4  11   6   6  16
# 26      Saleh   1            Sage  30  16  18  14  11   8  13   6   8
# 27       Ewan   1           Pupil  15   3   2   5   5   0   3   4   5
# 28     Cormag   9    Wyvern Rider  30  14   9  10   4  12   2   7  11
# 29     Rennac   1           Rogue  28  10  16  17   5   9  11   6   7
# 30    Duessel   8    Great Knight  41  17  12  12   8  17   9   6  15
# 31      Knoll  10          Shaman  22  13   9   8   0   2  10   5   7
# 32      Myrrh   1        Manakete  15   3   1   5   3   2   7   6   5
# 33     Syrene   1     Falcoknight  27  12  13  15  12  10  12   8   7
#
#                     Weapon Rank      Affin               Game
# 0                     [E Sword]    [Light]  the-sacred-stones
# 1            [A Sword, A Lance]    [Anima]  the-sacred-stones
# 2            [E Sword, D Lance]    [Light]  the-sacred-stones
# 3                     [C Lance]  [Thunder]  the-sacred-stones
# 4                     [D Lance]    [Anima]  the-sacred-stones
# 5                     [C Staff]    [Anima]  the-sacred-stones
# 6                       [E Axe]     [Fire]  the-sacred-stones
# 7                       [C Axe]     [Fire]  the-sacred-stones
# 8                       [D Bow]     [Fire]  the-sacred-stones
# 9                     [E Sword]    [Light]  the-sacred-stones
# 10                    [E Light]      [Ice]  the-sacred-stones
# 11                    [C Anima]    [Anima]  the-sacred-stones
# 12                    [D Staff]      [Ice]  the-sacred-stones
# 13                    [C Sword]     [Wind]  the-sacred-stones
# 14                    [D Lance]     [Fire]  the-sacred-stones
# 15           [D Sword, C Lance]     [Wind]  the-sacred-stones
# 16           [D Sword, C Lance]      [Ice]  the-sacred-stones
# 17           [A Sword, A Lance]     [Dark]  the-sacred-stones
# 18                    [D Lance]     [Wind]  the-sacred-stones
# 19                    [E Lance]  [Thunder]  the-sacred-stones
# 20                      [A Bow]      [Ice]  the-sacred-stones
# 21                    [C Sword]  [Thunder]  the-sacred-stones
# 22                            –     [Fire]  the-sacred-stones
# 23                    [D Sword]      [Ice]  the-sacred-stones
# 24                    [D Staff]    [Light]  the-sacred-stones
# 25                      [B Axe]  [Thunder]  the-sacred-stones
# 26  [A Anima, B Light, C Staff]     [Wind]  the-sacred-stones
# 27                    [E Anima]    [Light]  the-sacred-stones
# 28                    [C Lance]     [Fire]  the-sacred-stones
# 29                    [B Sword]     [Dark]  the-sacred-stones
# 30    [A Sword, A Lance, A Axe]    [Anima]  the-sacred-stones
# 31                     [C Dark]     [Dark]  the-sacred-stones
# 32                            –     [Wind]  the-sacred-stones
# 33           [C Sword, A Lance]  [Thunder]  the-sacred-stones
#        Name  Lv          Class  HP Str Skl Spd Lck Def Res Mov Con  \
# 0  Caellach  12           Hero  47  19  14  13  14  15  13   6  13
# 1     Orson  13        Paladin  48  18  15  14   6  14  11   8  12
# 2      Riev  16         Bishop  49  14  21  19   9  16  18   6   7
# 3   Ismaire   9    Swordmaster  33  16  20  23  12   8  15   6   7
# 4    Selena  11    Mage Knight  38  13  13  16  10  11  17   7   6
# 5      Glen  12    Wyvern Lord  46  20  17  13   7  18   5   8  12
# 6    Hayden  10         Ranger  37  17  14  15  17  12  12   7  10
# 7    Valter  13  Wyvern Knight  45  19  17  17   3  13  12   8  11
# 8      Fado  11        General  46  20  14  12   5  18  11   5  18
# 9      Lyon  14    Necromancer  44  22  13  11   4  17  19   6   7
#
#                  Weapon Rank      Affin               Game
# 0           [A Sword, A Axe]  [Thunder]  the-sacred-stones
# 1         [A Sword, A Lance]     [Dark]  the-sacred-stones
# 2         [S Light, A Staff]     [Dark]  the-sacred-stones
# 3                  [A Sword]     [Wind]  the-sacred-stones
# 4         [A Anima, B Staff]  [Thunder]  the-sacred-stones
# 5         [A Sword, A Lance]     [Wind]  the-sacred-stones
# 6           [A Sword, A Bow]    [Anima]  the-sacred-stones
# 7                  [S Lance]      [Ice]  the-sacred-stones
# 8  [A Sword, A Lance, A Axe]     [Fire]  the-sacred-stones
# 9          [S Dark, A Staff]      [Ice]  the-sacred-stones

# %%
for index, df in enumerate(dataframes):
    if index == 0:
        df['creature_campaign'] = False
    else:
        df['creature_campaign'] = True

df = pd.concat([dataframes[0], dataframes[1]], ignore_index=True)
display(df)
# Out:
#          Name  Lv           Class  HP Str Skl Spd Lck Def Res Mov Con  \
# 0      Eirika   1            Lord  16   4   8   9   5   3   1   5   5
# 1        Seth   1         Paladin  30  14  13  12  13  11   8   8  11
# 2       Franz   1        Cavalier  20   7   5   7   2   6   1   7   9
# 3     Gilliam   4          Knight  25   9   6   3   3   9   3   4  14
# 4     Vanessa   1  Pegasus Knight  17   5   7  11   4   6   5   7   5
# 5     Moulder   3          Priest  20   4   6   9   1   2   5   5   9
# 6        Ross   1      Journeyman  15   5   2   3   8   3   0   4   8
# 7      Garcia   4         Fighter  28   8   7   7   3   5   1   5  14
# 8       Neimi   1          Archer  17   4   5   6   4   3   2   5   5
# 9        Colm   2           Thief  18   4   4  10   8   3   1   6   6
# 10      Artur   2            Monk  19   6   6   8   2   2   6   5   6
# 11       Lute   1            Mage  17   6   6   7   8   3   5   5   3
# 12    Natasha   1          Cleric  18   2   4   8   6   2   6   5   4
# 13     Joshua   5        Myrmidon  24   8  13  14   7   5   2   5   8
# 14    Ephraim   4            Lord  23   8   9  11   8   7   2   5   8
# 15      Forde   6        Cavalier  24   7   8   8   7   8   2   7   9
# 16       Kyle   5        Cavalier  25   9   6   7   6   9   1   7  10
# 17      Orson   3         Paladin  34  15  13  11   4  13   7   8  12
# 18       Tana   4  Pegasus Knight  20   7   9  13   8   6   7   7   5
# 19     Amelia   1         Recruit  16   4   3   4   6   2   3   4   6
# 20      Innes   1          Sniper  31  14  13  15  14  10   9   6   9
# 21      Gerik  10       Mercenary  32  14  13  13   8  10   4   5  13
# 22     Tethys   1          Dancer  18   1   2  12  10   5   4   5   5
# 23     Marisa   5        Myrmidon  23   7  12  13   9   4   3   5   5
# 24  L’Arachel   3      Troubadour  18   6   6  10  12   5   8   6   5
# 25      Dozla   1       Berserker  43  16  11   9   4  11   6   6  16
# 26      Saleh   1            Sage  30  16  18  14  11   8  13   6   8
# 27       Ewan   1           Pupil  15   3   2   5   5   0   3   4   5
# 28     Cormag   9    Wyvern Rider  30  14   9  10   4  12   2   7  11
# 29     Rennac   1           Rogue  28  10  16  17   5   9  11   6   7
# 30    Duessel   8    Great Knight  41  17  12  12   8  17   9   6  15
# 31      Knoll  10          Shaman  22  13   9   8   0   2  10   5   7
# 32      Myrrh   1        Manakete  15   3   1   5   3   2   7   6   5
# 33     Syrene   1     Falcoknight  27  12  13  15  12  10  12   8   7
# 34   Caellach  12            Hero  47  19  14  13  14  15  13   6  13
# 35      Orson  13         Paladin  48  18  15  14   6  14  11   8  12
# 36       Riev  16          Bishop  49  14  21  19   9  16  18   6   7
# 37    Ismaire   9     Swordmaster  33  16  20  23  12   8  15   6   7
# 38     Selena  11     Mage Knight  38  13  13  16  10  11  17   7   6
# 39       Glen  12     Wyvern Lord  46  20  17  13   7  18   5   8  12
# 40     Hayden  10          Ranger  37  17  14  15  17  12  12   7  10
# 41     Valter  13   Wyvern Knight  45  19  17  17   3  13  12   8  11
# 42       Fado  11         General  46  20  14  12   5  18  11   5  18
# 43       Lyon  14     Necromancer  44  22  13  11   4  17  19   6   7
#
#                     Weapon Rank      Affin               Game  \
# 0                     [E Sword]    [Light]  the-sacred-stones
# 1            [A Sword, A Lance]    [Anima]  the-sacred-stones
# 2            [E Sword, D Lance]    [Light]  the-sacred-stones
# 3                     [C Lance]  [Thunder]  the-sacred-stones
# 4                     [D Lance]    [Anima]  the-sacred-stones
# 5                     [C Staff]    [Anima]  the-sacred-stones
# 6                       [E Axe]     [Fire]  the-sacred-stones
# 7                       [C Axe]     [Fire]  the-sacred-stones
# 8                       [D Bow]     [Fire]  the-sacred-stones
# 9                     [E Sword]    [Light]  the-sacred-stones
# 10                    [E Light]      [Ice]  the-sacred-stones
# 11                    [C Anima]    [Anima]  the-sacred-stones
# 12                    [D Staff]      [Ice]  the-sacred-stones
# 13                    [C Sword]     [Wind]  the-sacred-stones
# 14                    [D Lance]     [Fire]  the-sacred-stones
# 15           [D Sword, C Lance]     [Wind]  the-sacred-stones
# 16           [D Sword, C Lance]      [Ice]  the-sacred-stones
# 17           [A Sword, A Lance]     [Dark]  the-sacred-stones
# 18                    [D Lance]     [Wind]  the-sacred-stones
# 19                    [E Lance]  [Thunder]  the-sacred-stones
# 20                      [A Bow]      [Ice]  the-sacred-stones
# 21                    [C Sword]  [Thunder]  the-sacred-stones
# 22                            –     [Fire]  the-sacred-stones
# 23                    [D Sword]      [Ice]  the-sacred-stones
# 24                    [D Staff]    [Light]  the-sacred-stones
# 25                      [B Axe]  [Thunder]  the-sacred-stones
# 26  [A Anima, B Light, C Staff]     [Wind]  the-sacred-stones
# 27                    [E Anima]    [Light]  the-sacred-stones
# 28                    [C Lance]     [Fire]  the-sacred-stones
# 29                    [B Sword]     [Dark]  the-sacred-stones
# 30    [A Sword, A Lance, A Axe]    [Anima]  the-sacred-stones
# 31                     [C Dark]     [Dark]  the-sacred-stones
# 32                            –     [Wind]  the-sacred-stones
# 33           [C Sword, A Lance]  [Thunder]  the-sacred-stones
# 34             [A Sword, A Axe]  [Thunder]  the-sacred-stones
# 35           [A Sword, A Lance]     [Dark]  the-sacred-stones
# 36           [S Light, A Staff]     [Dark]  the-sacred-stones
# 37                    [A Sword]     [Wind]  the-sacred-stones
# 38           [A Anima, B Staff]  [Thunder]  the-sacred-stones
# 39           [A Sword, A Lance]     [Wind]  the-sacred-stones
# 40             [A Sword, A Bow]    [Anima]  the-sacred-stones
# 41                    [S Lance]      [Ice]  the-sacred-stones
# 42    [A Sword, A Lance, A Axe]     [Fire]  the-sacred-stones
# 43            [S Dark, A Staff]      [Ice]  the-sacred-stones
#
#     creature_campaign
# 0               False
# 1               False
# 2               False
# 3               False
# 4               False
# 5               False
# 6               False
# 7               False
# 8               False
# 9               False
# 10              False
# 11              False
# 12              False
# 13              False
# 14              False
# 15              False
# 16              False
# 17              False
# 18              False
# 19              False
# 20              False
# 21              False
# 22              False
# 23              False
# 24              False
# 25              False
# 26              False
# 27              False
# 28              False
# 29              False
# 30              False
# 31              False
# 32              False
# 33              False
# 34               True
# 35               True
# 36               True
# 37               True
# 38               True
# 39               True
# 40               True
# 41               True
# 42               True
# 43               True

# %%
df.columns
# Out:
# Index(['Name', 'Lv', 'Class', 'HP', 'Str', 'Skl', 'Spd', 'Lck', 'Def', 'Res',
#        'Mov', 'Con', 'Weapon Rank', 'Affin', 'Game', 'creature_campaign'],
#       dtype='object')

# %%
df.to_csv('../data/the-sacred-stones/base-stats.csv', index=False)

# %% [markdown]
# ## Fixing Weapon Ranks and Affinity Columns
#
# Changes have already been made to the scraping function, but this section shows my messin' around.

# %%
import re

seth = tables[0].find_all('tr')[2]
weapon_info = seth.find_all('td')[-2]
affinity = seth.find_all('td')[-1]
print(f"Weapon html: {weapon_info.prettify()}\n\nAffinity html: {affinity.prettify()}")
# Out:
# Weapon html: <td>
#  <a href="https://serenesforest.net/wp-content/uploads/2014/04/TypeSword.gif">
#   <img alt="Sword" class="alignnone size-full" src="https://serenesforest.net/wp-content/uploads/2014/04/TypeSword.gif"/>
#  </a>
#  A,
#  <a href="https://serenesforest.net/wp-content/uploads/2014/04/TypeLance.gif">
#   <img alt="Lance" class="alignnone size-full" src="https://serenesforest.net/wp-content/uploads/2014/04/TypeLance.gif"/>
#  </a>
#  A
# </td>
#
#
# Affinity html: <td>
#  <a href="https://serenesforest.net/wp-content/uploads/2014/04/AffinAnima.gif">
#   <img alt="Anima" class="alignnone size-full" src="https://serenesforest.net/wp-content/uploads/2014/04/AffinAnima.gif"/>
#  </a>
# </td>

# %%
affinity_type = affinity.find('img')['alt']
affinity_type
# Out:
# 'Anima'

# %%
weapon_types = weapon_info.find_all('img')
weapon_types = [weapon['alt'] for weapon in weapon_types]
weapon_types
# Out:
# ['Sword', 'Lance']

# %%
ranks = weapon_info.text.replace(',', '').split()
ranks
# Out:
# ['A', 'A']

# %%
print(f"Weapons: {weapon_types}\nRanks: {ranks}")
# Out:
# Weapons: ['Sword', 'Lance']
# Ranks: ['A', 'A']

# %%
weapon_ranks = [f"{ranks[i]} {weapon}" for i, weapon in enumerate(weapon_types)]
weapon_ranks
# Out:
# ['A Sword', 'A Lance']

# %%
def extract_alt_text(image_info):
    
    if image_info['alt']:
        return image_info['alt']

# %%
for image in weapon_info.find_all('img'):
    print(extract_alt_text(image))
# Out:
# Sword
# Lance

# %%
for x in weapon_info:
    print("---")
    print(x)
# Out:
# ---
# <a href="https://serenesforest.net/wp-content/uploads/2014/04/TypeSword.gif"><img alt="Sword" class="alignnone size-full" src="https://serenesforest.net/wp-content/uploads/2014/04/TypeSword.gif"/></a>
# ---
#  A,
# ---
# <a href="https://serenesforest.net/wp-content/uploads/2014/04/TypeLance.gif"><img alt="Lance" class="alignnone size-full" src="https://serenesforest.net/wp-content/uploads/2014/04/TypeLance.gif"/></a>
# ---
#  A

# %% [markdown]
# ## Creating Full Dataset

# %%
dir = '../data/the-sacred-stones'
bases = pd.read_csv(f'{dir}/base-stats.csv')
growths = pd.read_csv(f'{dir}/growth-rates.csv')

# %%
growths.head()
# Out:
#       Name  HP  S/M  Skl  Spd  Lck  Def  Res               Game
# 0   Eirika  70   40   60   60   60   30   30  the-sacred-stones
# 1     Seth  90   50   45   45   25   40   30  the-sacred-stones
# 2    Franz  80   40   40   50   40   25   20  the-sacred-stones
# 3  Gilliam  90   45   35   30   30   55   20  the-sacred-stones
# 4  Moulder  70   40   50   40   20   25   25  the-sacred-stones

# %%
ssdf = (
    growths
    .drop('Game', axis='columns')
    .merge(bases, how='outer', on='Name', suffixes=['_growth', '_base'])
)

float_columns = ssdf.select_dtypes(include='float').columns
ssdf[float_columns] = ssdf[float_columns].astype('Int64')

display(ssdf.head())
# Out:
#       Name  HP_growth  S/M  Skl_growth  Spd_growth  Lck_growth  Def_growth  \
# 0   Eirika         70   40          60          60          60          30
# 1     Seth         90   50          45          45          25          40
# 2    Franz         80   40          40          50          40          25
# 3  Gilliam         90   45          35          30          30          55
# 4  Moulder         70   40          50          40          20          25
#
#    Res_growth  Lv     Class  ...  Spd_base  Lck_base  Def_base  Res_base  Mov  \
# 0          30   1      Lord  ...         9         5         3         1    5
# 1          30   1   Paladin  ...        12        13        11         8    8
# 2          20   1  Cavalier  ...         7         2         6         1    7
# 3          20   4    Knight  ...         3         3         9         3    4
# 4          25   3    Priest  ...         9         1         2         5    5
#
#    Con             Weapon Rank        Affin               Game  \
# 0    5             ['E Sword']    ['Light']  the-sacred-stones
# 1   11  ['A Sword', 'A Lance']    ['Anima']  the-sacred-stones
# 2    9  ['E Sword', 'D Lance']    ['Light']  the-sacred-stones
# 3   14             ['C Lance']  ['Thunder']  the-sacred-stones
# 4    9             ['C Staff']    ['Anima']  the-sacred-stones
#
#   creature_campaign
# 0             False
# 1             False
# 2             False
# 3             False
# 4             False
#
# [5 rows x 23 columns]

# %%
ssdf.to_csv(f'{dir}/full_df.csv')

# %% [markdown]
# # Testing on Binding Blade (FE6)

# %%
url = "https://serenesforest.net/binding-blade/characters/growth-rates/"
page = requests.get(url)
soup = BeautifulSoup(page.content, "html.parser")
tables = soup.find_all("table")
dataframes = [scrape_table(table, 'binding-blade') for table in tables]

for df in dataframes:
    display(df.head(10))
# Out:
#        Name   HP S/M Skl Spd  Lck Def Res           Game
# 0       Roy   80  40  50  40   60  25  30  binding-blade
# 1    Marcus   60  25  20  25   20  15  20  binding-blade
# 2     Allen   85  45  40  45   40  25  10  binding-blade
# 3     Lance   80  40  45  50   35  20  15  binding-blade
# 4      Wolt   80  40  50  40   40  20  10  binding-blade
# 5      Bors   90  30  30  40   50  35  10  binding-blade
# 6  Merlinus  100   0  50  50  100  20   5  binding-blade
# 7     Ellen   45  50  30  20   70   5  60  binding-blade
# 8     Dieck   90  40  40  30   35  20  15  binding-blade
# 9      Wade   75  50  45  20   45  30   5  binding-blade

# %%
def table_to_df(url: str, game: str) -> pd.DataFrame:
    page = requests.get(url)
    soup = BeautifulSoup(page.content, "html.parser")
    tables = soup.find_all("table")
    dataframes = [scrape_table(table, game) for table in tables]

    return dataframes

# %%
game = 'binding-blade'
table_names = ['growth-rates', 'base-stats']
dataframes = []
for table_name in table_names:
    url = f"https://serenesforest.net/{game}/characters/{table_name}/"
    dfs = table_to_df(url, game)
    for df in dfs:
        display(df.head(5))
        dataframes.append(df)
# Out:
#      Name  HP S/M Skl Spd Lck Def Res           Game
# 0     Roy  80  40  50  40  60  25  30  binding-blade
# 1  Marcus  60  25  20  25  20  15  20  binding-blade
# 2   Allen  85  45  40  45  40  25  10  binding-blade
# 3   Lance  80  40  45  50  35  20  15  binding-blade
# 4    Wolt  80  40  50  40  40  20  10  binding-blade
#      Name     Class Lv  HP S/M Skl Spd Lck Def Res Con Mov         Affin  \
# 0     Roy      Lord  1  18   5   5   7   7   5   0   6   5        [Fire]
# 1  Marcus   Paladin  1  32   9  14  11  10   9   8  11   8         [Ice]
# 2   Allen  Cavalier  1  21   7   4   6   3   6   0   9   7        [Fire]
# 3   Lance  Cavalier  1  20   5   6   8   2   6   0   9   7  [AffinAnima]
# 4    Wolt    Archer  1  18   4   4   5   2   4   0   7   5         [Ice]
#
#                 Weapon ranks           Game
# 0                  [D Sword]  binding-blade
# 1  [D Sword, A Lance, E Axe]  binding-blade
# 2         [E Sword, D Lance]  binding-blade
# 3         [E Sword, D Lance]  binding-blade
# 4                    [D Bow]  binding-blade

# %%
growths, bases = dataframes

# %%
bbdf = (
    growths
    .drop('Game', axis='columns')
    .merge(bases, how='outer', on='Name', suffixes=['_growth', '_base'])
)

display(bbdf.head())
# Out:
#      Name HP_growth S/M_growth Skl_growth Spd_growth Lck_growth Def_growth  \
# 0     Roy        80         40         50         40         60         25
# 1  Marcus        60         25         20         25         20         15
# 2   Allen        85         45         40         45         40         25
# 3   Lance        80         40         45         50         35         20
# 4    Wolt        80         40         50         40         40         20
#
#   Res_growth     Class Lv  ... Skl_base Spd_base Lck_base Def_base Res_base  \
# 0         30      Lord  1  ...        5        7        7        5        0
# 1         20   Paladin  1  ...       14       11       10        9        8
# 2         10  Cavalier  1  ...        4        6        3        6        0
# 3         15  Cavalier  1  ...        6        8        2        6        0
# 4         10    Archer  1  ...        4        5        2        4        0
#
#   Con Mov         Affin               Weapon ranks           Game
# 0   6   5        [Fire]                  [D Sword]  binding-blade
# 1  11   8         [Ice]  [D Sword, A Lance, E Axe]  binding-blade
# 2   9   7        [Fire]         [E Sword, D Lance]  binding-blade
# 3   9   7  [AffinAnima]         [E Sword, D Lance]  binding-blade
# 4   7   5         [Ice]                    [D Bow]  binding-blade
#
# [5 rows x 22 columns]

# %%
bbdf.to_csv('../data/binding-blade/full_data.csv')

# %%
bbdf.loc[bbdf["Name"].str.contains("Cath")]
# Out:
#          Name HP_growth S/M_growth Skl_growth Spd_growth Lck_growth  \
# 38       Cath        80         40         45         85         50
# 60  Cath (HM)       NaN        NaN        NaN        NaN        NaN
#
#    Def_growth Res_growth  Class Lv  ... Skl_base Spd_base Lck_base Def_base  \
# 38         15         20  Thief  5  ...        7       11        8        2
# 60        NaN        NaN     20  3  ...       12        2        3     None
#
#    Res_base   Con   Mov         Affin Weapon ranks           Game
# 38        1     5     6  [AffinAnima]    [E Sword]  binding-blade
# 60     None  None  None          None         None  binding-blade
#
# [2 rows x 22 columns]

# %%
def extract_headers(row):
    return [header.text for header in row.find_all('th')]

def handle_rowspan(row_data, rowspan_data, row_index):
    for col_index in sorted(rowspan_data.keys()):
        rowspan_count, rowspan_text = rowspan_data[col_index]
        if rowspan_count > 0:
            while len(row_data) <= col_index:
                row_data.append('')
            row_data[col_index] = rowspan_text
            rowspan_data[col_index] = (rowspan_count - 1, rowspan_text)
    return row_data

def extract_cell_data(cell):
    images = cell.find_all('img')
    if images:
        alt_texts = [extract_alt_text(image) for image in images]
        if cell.text.strip():
            text = cell.text.replace(',', '').split()
            return [f"{text[i]} {alt_text}" for i, alt_text in enumerate(alt_texts)]
        else:
            return alt_texts
    return cell.text

def build_dataframe(data, columns, game_title):
    df = pd.DataFrame(data, columns=columns)
    df['Game'] = game_title
    return df

def scrape_table(table, game_title: str) -> pd.DataFrame:
    data, columns, header_found, rowspan_data = [], [], False, {}
    
    for row_index, row in enumerate(table.find_all('tr')):
        row_data, is_header = [], False
        
        if not header_found:
            headers = row.find_all('th')
            if headers:
                header_found = True
                is_header = True
                columns = extract_headers(row)
                
        if not is_header:
            # Handle row span from previous rows
            row_data = handle_rowspan(row_data, rowspan_data, row_index)
            
            for col_index, cell in enumerate(row.find_all(['td', 'th'], recursive=False), len(row_data)):
                if cell.has_attr("rowspan"):
                    rowspan_count = int(cell['rowspan']) - 1
                    rowspan_data[col_index + len(row_data)] = (rowspan_count, cell.text)
                cell_data = extract_cell_data(cell)
                while len(row_data) <= col_index:
                    row_data.append('')
                row_data[col_index] = cell_data
        
        if row_data:
            data.append(row_data)
            
    df = build_dataframe(data, columns, game_title)
    return df

# %%
game = 'binding-blade'
table_names = ['growth-rates', 'base-stats']
dataframes = []
for table_name in table_names:
    url = f"https://serenesforest.net/{game}/characters/{table_name}/"
    dfs = table_to_df(url, game)
    for df in dfs:
        display(df.head(5))
        # dataframes.append(df)
# Out:
#      Name  HP S/M Skl Spd Lck Def Res           Game
# 0     Roy  80  40  50  40  60  25  30  binding-blade
# 1  Marcus  60  25  20  25  20  15  20  binding-blade
# 2   Allen  85  45  40  45  40  25  10  binding-blade
# 3   Lance  80  40  45  50  35  20  15  binding-blade
# 4    Wolt  80  40  50  40  40  20  10  binding-blade
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/internals/construction.py:934, in _finalize_columns_and_data(content, columns, dtype)
#     933 try:
# --> 934     columns = _validate_or_indexify_columns(contents, columns)
#     935 except AssertionError as err:
#     936     # GH#26429 do not raise user-facing AssertionError
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/internals/construction.py:981, in _validate_or_indexify_columns(content, columns)
#     979 if not is_mi_list and len(columns) != len(content):  # pragma: no cover
#     980     # caller's responsibility to check for this...
# --> 981     raise AssertionError(
#     982         f"{len(columns)} columns passed, passed data had "
#     983         f"{len(content)} columns"
#     984     )
#     985 if is_mi_list:
#     986     # check if nested list column, length of each sub-list should be equal
#
# AssertionError: 14 columns passed, passed data had 35 columns
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[41], line 6
#       4 for table_name in table_names:
#       5     url = f"https://serenesforest.net/{game}/characters/{table_name}/"
# ----> 6     dfs = table_to_df(url, game)
#       7     for df in dfs:
#       8         display(df.head(5))
#
# Cell In[26], line 5, in table_to_df(url, game)
#       3 soup = BeautifulSoup(page.content, "html.parser")
#       4 tables = soup.find_all("table")
# ----> 5 dataframes = [scrape_table(table, game) for table in tables]
#       7 return dataframes
#
# Cell In[26], line 5, in <listcomp>(.0)
#       3 soup = BeautifulSoup(page.content, "html.parser")
#       4 tables = soup.find_all("table")
# ----> 5 dataframes = [scrape_table(table, game) for table in tables]
#       7 return dataframes
#
# Cell In[39], line 59, in scrape_table(table, game_title)
#      56     if row_data:
#      57         data.append(row_data)
# ---> 59 df = build_dataframe(data, columns, game_title)
#      60 return df
#
# Cell In[39], line 26, in build_dataframe(data, columns, game_title)
#      25 def build_dataframe(data, columns, game_title):
# ---> 26     df = pd.DataFrame(data, columns=columns)
#      27     df['Game'] = game_title
#      28     return df
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/frame.py:782, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     780     if columns is not None:
#     781         columns = ensure_index(columns)
# --> 782     arrays, columns, index = nested_data_to_arrays(
#     783         # error: Argument 3 to "nested_data_to_arrays" has incompatible
#     784         # type "Optional[Collection[Any]]"; expected "Optional[Index]"
#     785         data,
#     786         columns,
#     787         index,  # type: ignore[arg-type]
#     788         dtype,
#     789     )
#     790     mgr = arrays_to_mgr(
#     791         arrays,
#     792         columns,
#    (...)
#     795         typ=manager,
#     796     )
#     797 else:
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/internals/construction.py:498, in nested_data_to_arrays(data, columns, index, dtype)
#     495 if is_named_tuple(data[0]) and columns is None:
#     496     columns = ensure_index(data[0]._fields)
# --> 498 arrays, columns = to_arrays(data, columns, dtype=dtype)
#     499 columns = ensure_index(columns)
#     501 if index is None:
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/internals/construction.py:840, in to_arrays(data, columns, dtype)
#     837     data = [tuple(x) for x in data]
#     838     arr = _list_to_arrays(data)
# --> 840 content, columns = _finalize_columns_and_data(arr, columns, dtype)
#     841 return content, columns
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/internals/construction.py:937, in _finalize_columns_and_data(content, columns, dtype)
#     934     columns = _validate_or_indexify_columns(contents, columns)
#     935 except AssertionError as err:
#     936     # GH#26429 do not raise user-facing AssertionError
# --> 937     raise ValueError(err) from err
#     939 if len(contents) and contents[0].dtype == np.object_:
#     940     contents = convert_object_array(contents, dtype=dtype)
#
# ValueError: 14 columns passed, passed data had 35 columns
